# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re
# Out:
# /Users/ppadma/git_repo/github_repos/prasadpiyer.science/.venv/lib/python3.12/site-packages/pybtex/plugin/__init__.py:26: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    # "proceeding": {
    #     "file" : "deduped_pubs.bib",
    #     "venuekey": "booktitle",
    #     "venue-pretext": "In the proceedings of ",
    #     "collection" : {"name":"publications",
    #                     "permalink":"/publication/"}
        
    # },
    "journal":{
        "file": "deduped_pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    print(publist)
    bibdata = parser.parse_file(publist[pubsource]["file"])
    
    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# {'journal': {'file': 'deduped_pubs.bib', 'venuekey': 'journal', 'venue-pretext': '', 'collection': {'name': 'publications', 'permalink': '/publication/'}}}
# SUCESSFULLY PARSED P.2025: " AutoSciLab: A Self-Driving Laboratory for Interpretable Scie ... "
# SUCESSFULLY PARSED P.2025_2: " Efficient single-photon emission via quantum-confined charge ... "
# SUCESSFULLY PARSED P.2025_3: " High-Q, size-independent, and reconfigurable optical antenna ... "
# SUCESSFULLY PARSED P.2024: " AI for Technoscientific Discovery: A Human-Inspired Architec ... "
# SUCESSFULLY PARSED P.2024_2: " AutoSciLab: A Self-Driving Laboratory For Interpretable Scie ... "
# SUCESSFULLY PARSED P.2024_3: " Enhancement of non-classical radiation from quantum dots emb ... "
# SUCESSFULLY PARSED P.2024_4: " Machine learning discovers parsimonious equations governing  ... "
# SUCESSFULLY PARSED P.2024_5: " Mie metasurfaces for enhancing photon outcoupling from singl ... "
# SUCESSFULLY PARSED P.2024_6: " Self-driving lab discovers high-efficiency directional incoh ... "
# SUCESSFULLY PARSED P.2024_7: " Self-driving lab discovers principles for steering spontaneo ... "
# SUCESSFULLY PARSED P.2024_8: " Time Domain Phase Engineering of Metasurfaces Enables Passiv ... "
# SUCESSFULLY PARSED P.2024_9: " Ultrafast non-reciprocal spin resonances in frustrated plasm ... "
# WARNING Missing Expected Field 'journal' from entry Iyer_2023: " Learning incoherent light emis ... "
# SUCESSFULLY PARSED P.2023: " Control of Quantized Spontaneous Emission from Single GaAs Q ... "
# SUCESSFULLY PARSED P.2023_2: " InAs based Nonlinear Dielectric Metasurface for Binary Phase ... "
# SUCESSFULLY PARSED P.2023_3: " InAs based Nonlinear Dielectric Metasurface for Binary Phase ... "
# SUCESSFULLY PARSED P.2023_4: " Photoconductive Metasurfaces for Near-Field Terahertz Source ... "
# SUCESSFULLY PARSED P.2023_5: " Sub-picosecond steering of ultrafast incoherent emission fro ... "
# SUCESSFULLY PARSED P.2023_6: " Ultrafast reconfigurability of circular dichroism from bound ... "
# SUCESSFULLY PARSED P.2023_7: " Ultrafast reconfigurability of circular dichroism from bound ... "
# WARNING Missing Expected Field 'journal' from entry Prasad_P._Iyer_120864497: " Liquid crystal metasurfaces wi ... "
# SUCESSFULLY PARSED Gennaro_2022: " Cascaded Optical Nonlinearities in Dielectric Metasurfaces  "
# SUCESSFULLY PARSED P.2022: " Cascaded Second Order Optical Nonlinearities in a Dielectric ... "
# SUCESSFULLY PARSED P.2022_2: " Cascaded Second Order Optical Nonlinearities in a Dielectric ... "
# WARNING Missing Expected Field 'journal' from entry https://doi.org/10.48550/arxiv.2206.04645: " Sub picosecond steering of ult ... "
# SUCESSFULLY PARSED P.2022_3: " Terahertz Pulse Generation with Binary Phase Control in Nonl ... "
# SUCESSFULLY PARSED P.2022_4: " Terahertz pulse generation with binary phase control in non- ... "
# WARNING Missing Expected Field 'journal' from entry Iyer_2022: " Ultrafast beam steering of pho ... "
# SUCESSFULLY PARSED P.2022_5: " Ultrafast beam steering of photoluminescence from dielectric ... "
# SUCESSFULLY PARSED P.2022_6: " Ultrafast beam steering of photoluminescence from dielectric ... "
# SUCESSFULLY PARSED Mohtashami_2021: " Light-emitting metalenses and meta-axicons for focusing and  ... "
# WARNING Missing Expected Field 'journal' from entry Mohtashami_2021_2: " Luminescent Metalenses for Foc ... "
# WARNING Missing Expected Field 'journal' from entry Gennaro_2021: " Cascaded Second Order Optical  ... "
# SUCESSFULLY PARSED P.2021: " Cascaded Second Order Optical Nonlinearities in a Dielectric ... "
# SUCESSFULLY PARSED P.2021_2: " Cascaded optical nonlinearities in dielectric metasurfaces  "
# SUCESSFULLY PARSED Iyer_2020: " Unidirectional luminescence from {InGaN}/{GaN} quantum-well  ... "
# SUCESSFULLY PARSED P.2020: " Light-Emitting Metasurfaces: A Metalens Approach for Focusin ... "
# SUCESSFULLY PARSED P.2020_2: " Light-emitting metasurfaces: A metalens approach for focusin ... "
# SUCESSFULLY PARSED P.2020_3: " Tunable and reconfigurable high-index semiconductor meta-opt ... "
# SUCESSFULLY PARSED P.2020_4: " Unidirectional Luminescence from InGaN/GaN Quantum-Well Meta ... "
# SUCESSFULLY PARSED P.2020_5: " Unidirectional luminescence from InGaN/GaN quantum-well meta ... "
# SUCESSFULLY PARSED P.2020_6: " Widely Tunable Optical and Thermal Properties of Dirac Semim ... "
# WARNING Missing Expected Field 'journal' from entry Prasad_P._Iyer_57630392: " Unidirectional Luminescence fr ... "
# WARNING Missing Expected Field 'journal' from entry Chorsi_2019: " Topological Dirac semi-metals: ... "
# SUCESSFULLY PARSED P.2019: " Gate-tunable metafilm absorber based on indium silicon oxide  "
# SUCESSFULLY PARSED P.2019_2: " III-V Heterojunction Platform for Electrically Reconfigurabl ... "
# SUCESSFULLY PARSED P.2019_3: " Reconfigurable semiconductor Mie-resonant meta-optics  "
# SUCESSFULLY PARSED P.2019_4: " Thermally Reconfigurable Meta-Optics  "
# SUCESSFULLY PARSED P.2019_5: " Tunable Metasurface based on Silicon Doped Indium Oxide  "
# SUCESSFULLY PARSED P.2019_6: " Unidirectional Luminescence from Quantum Well Metasurfaces  "
# SUCESSFULLY PARSED P.2019_7: " Widely tunable optical and thermal properties of Dirac semim ... "
# WARNING Missing Expected Field 'journal' from entry Prasad_P._Iyer_57630367: " Device Platform for Electrical ... "
# SUCESSFULLY PARSED Butakov_2018_paper: " Broadband Electrically Tunable Dielectric Resonators Using M ... "
# SUCESSFULLY PARSED Iyer_2018: " Uniform Thermo-Optic Tunability of Dielectric Metalenses  "
# WARNING Missing Expected Field 'journal' from entry Butakov_2018: " Electrically Switchable Infrar ... "
# SUCESSFULLY PARSED P.2018: " Device platform for electrically reconfigurable dielectric m ... "
# WARNING Missing Expected Field 'journal' from entry Iyer_2017: " Reconfigurable Mie resonators  ... "
# SUCESSFULLY PARSED P.2017: " Ultra-wide plasmonic tuning of semiconductor metasurface res ... "
# SUCESSFULLY PARSED P.2017_2: " Ultrawide thermal free-carrier tuning of dielectric antennas ... "
# WARNING Missing Expected Field 'journal' from entry Lewi_2016: " Widely tunable infrared semico ... "
# SUCESSFULLY PARSED P.2016: " Electrically Reconfigurable Metasurfaces Using Heterojunctio ... "
# WARNING Missing Expected Field 'journal' from entry Iyer_2015: " Dynamically reconfigurable met ... "
# WARNING Missing Expected Field 'journal' from entry Lewi_2015: " Properties of infrared doped s ... "
# SUCESSFULLY PARSED P.2015: " Beam engineering for selective and enhanced coupling to mult ... "
# SUCESSFULLY PARSED P.2015_2: " Reconfigurable Semiconductor Phased-Array Metasurfaces  "
# SUCESSFULLY PARSED P.2015_3: " Widely Tunable Infrared Antennas Using Free Carrier Refracti ... "
# SUCESSFULLY PARSED Bhatta_2014: " A brief review of Badger{\textendash}Bauer rule and its vali ... "
